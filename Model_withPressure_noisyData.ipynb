# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
N_train = 5000
N_val = 5000
N_test = 5000

path = '/content/drive/MyDrive/Dataset/dati_progetto.csv'
df = pd.read_csv(path)

df_t_v = df[df['t'] != 10]
df_test = df[df['t'] == 10]

# %%
X = torch.tensor(df_t_v['x'].values, dtype=torch.float32, requires_grad=True).reshape(-1,1)
Y = torch.tensor(df_t_v['y'].values, dtype=torch.float32, requires_grad=True).reshape(-1,1)
T = torch.tensor(df_t_v['t'].values, dtype=torch.float32, requires_grad=True).reshape(-1,1)

U = torch.tensor(df_t_v['u'].values, dtype=torch.float32).reshape(-1,1)
V = torch.tensor(df_t_v['v'].values, dtype=torch.float32).reshape(-1,1)
P = torch.tensor(df_t_v['p'].values, dtype=torch.float32).reshape(-1,1)

NN = 5000 #discretizzazione spaziale
TT = 200 #discretizzazione temporale

np.random.seed(123)

idx = np.random.choice(NN * TT - NN, N_train, replace=False)

x_train = X[idx, :].to(device)
y_train = Y[idx, :].to(device)
t_train = T[idx, :].to(device)
u_train = U[idx, :]
v_train = V[idx, :]
p_train = P[idx, :]

zeros_train = torch.zeros_like(x_train).to(device)

idx_val = np.setdiff1d(np.arange(NN * TT - NN), idx)
idx2 = np.random.choice(idx_val, N_val, replace=False)

x_val = X[idx2, :].to(device)
y_val = Y[idx2, :].to(device)
t_val = T[idx2, :].to(device)
u_val = U[idx2, :].to(device)
v_val = V[idx2, :].to(device)
p_val = P[idx2, :].to(device)

# %%
noise = 0.05
u_n_train = (u_train + noise * torch.std(u_train) * torch.randn(u_train.shape)).to(device)
v_n_train = (v_train + noise * torch.std(v_train) * torch.randn(v_train.shape)).to(device)
p_n_train = (p_train + noise * torch.std(p_train) * torch.randn(p_train.shape)).to(device)

# %%
x_test = torch.tensor(df_test['x'].values, dtype=torch.float32, requires_grad=True).reshape(-1,1).to(device)
y_test = torch.tensor(df_test['y'].values, dtype=torch.float32, requires_grad=True).reshape(-1,1).to(device)
t_test = torch.tensor(df_test['t'].values, dtype=torch.float32, requires_grad=True).reshape(-1,1).to(device)
u_test = torch.tensor(df_test['u'].values, dtype=torch.float32, requires_grad=True).reshape(-1,1).to(device)
v_test = torch.tensor(df_test['v'].values, dtype=torch.float32, requires_grad=True).reshape(-1,1).to(device)
p_test = torch.tensor(df_test['p'].values, dtype=torch.float32, requires_grad=True).reshape(-1,1).to(device)

# %%
x_graph, y_graph = x_train.cpu().detach().numpy(), y_train.cpu().detach().numpy()
t_graph = t_train.cpu().detach().numpy()
fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')

ax.scatter( x_graph, t_graph, y_graph,  c='b', s=4, marker='o')
ax.set_xlabel('x')
ax.set_ylabel('t')
ax.set_zlabel('y')
ax.yaxis.labelpad = 30
ax.set_title('Training Points')
# Imposta la stessa scala su tutti e tre gli assi
ax.set_box_aspect([np.ptp(coord) for coord in [x_graph, t_graph, y_graph]])
ax.grid(False)

# %%
x_graph, y_graph = x_val.cpu().detach().numpy(), y_val.cpu().detach().numpy()
t_graph = t_val.cpu().detach().numpy()
fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')

ax.scatter( x_graph, t_graph, y_graph,  c='g', s=4, marker='o')
ax.set_xlabel('x')
ax.set_ylabel('t')
ax.set_zlabel('y')
ax.yaxis.labelpad = 30
ax.set_title('Validation Points')
# Imposta la stessa scala su tutti e tre gli assi
ax.set_box_aspect([np.ptp(coord) for coord in [x_graph, t_graph, y_graph]])
ax.grid(False)

# %%
class FCN(nn.Module):
    '''
    Creazione di una NN fully-connected in PyTorch
    '''
    def __init__(self, N_INPUT, N_OUTPUT, N_HIDDEN, N_LAYERS):
        super().__init__()
        activation = nn.Tanh
        self.fcs = nn.Sequential(*[
                        nn.Linear(N_INPUT, N_HIDDEN),
                        activation()])
        self.fch = nn.Sequential(*[
                        nn.Sequential(*[
                            nn.Linear(N_HIDDEN, N_HIDDEN),
                            activation()]) for _ in range(N_LAYERS-1)])
        self.fce = nn.Linear(N_HIDDEN, N_OUTPUT)

    def forward(self, x):
        x = self.fcs(x)
        x = self.fch(x)
        x = self.fce(x)
        return x

# %%
def pde(x,y,t,nu,model):

  output_pinn = model(torch.hstack((x, y, t)))

  u, v, p = output_pinn[:, 0:1], output_pinn[:, 1:2], output_pinn[:, 2:3]

  u_x = torch.autograd.grad(u, x, torch.ones_like(u), create_graph=True)[0]
  u_xx = torch.autograd.grad(u_x, x, torch.ones_like(u_x), create_graph=True)[0]
  u_y = torch.autograd.grad(u, y, torch.ones_like(u), create_graph=True)[0]
  u_yy = torch.autograd.grad(u_y, y, torch.ones_like(u_y), create_graph=True)[0]
  u_t = torch.autograd.grad(u, t, torch.ones_like(u), create_graph=True)[0]

  v_x = torch.autograd.grad(v, x, torch.ones_like(v), create_graph=True)[0]
  v_xx = torch.autograd.grad(v_x, x, torch.ones_like(v_x), create_graph=True)[0]
  v_y = torch.autograd.grad(v, y, torch.ones_like(v), create_graph=True)[0]
  v_yy = torch.autograd.grad(v_y, y, torch.ones_like(v_y), create_graph=True)[0]
  v_t = torch.autograd.grad(v, t, torch.ones_like(v), create_graph=True)[0]

  p_x = torch.autograd.grad(p, x, torch.ones_like(p), create_graph=True)[0]
  p_y = torch.autograd.grad(p, y, torch.ones_like(p), create_graph=True)[0]

  f = u_t + u * u_x + v * u_y + p_x - nu.to(device) * (u_xx + u_yy)
  g = v_t + u * v_x + v * v_y + p_y - nu.to(device) * (v_xx + v_yy)
  h = u_x + v_y

  return u, v, p, f, g, h

# %%
def physics_loss(f,g,h,zeros_train, criterion):

  f_loss = criterion(f, zeros_train)
  g_loss = criterion(g, zeros_train)
  h_loss = criterion(h, zeros_train)

  return f_loss + g_loss + h_loss

# %%
def data_loss(u, v, p, u_data, v_data, p_data, criterion):

  u_loss = criterion(u, u_data)
  v_loss = criterion(v, v_data)
  p_loss = criterion(p, p_data)

  return u_loss + v_loss + p_loss

# %%
def loss_val_set(x_val, y_val, t_val, u_val, v_val, p_val, nu, model, zeros_train, criterion):

  o1, o2, o3, o4, o5, o6 = pde(x_val, y_val, t_val, nu, model)

  data_loss_val = data_loss(o1, o2, o3, u_val, v_val, p_val, criterion)
  physics_loss_val = physics_loss(o4, o5, o6, zeros_train, criterion)

  loss_val = data_loss_val + physics_loss_val

  return loss_val

# %%
def early_stopping(train_loss, val_loss, par):
  if (par < 0.01048) and (train_loss < 1.2e-4) and (val_loss < 3e-4):
    return True

# %%
'''
torch.manual_seed(123)

pinn = FCN(3,3,50,6).to(device)

num_iterations = 150000

nu = torch.nn.Parameter(torch.zeros(1, requires_grad=True))

optimizer = torch.optim.Adam(list(pinn.parameters())+[nu], lr=1e-3)
criterion = nn.MSELoss()

losses = []
nus = []
val_losses = []

for i in range(num_iterations+1):

  optimizer.zero_grad()

  u, v, p, f, g, h = pde(x_train, y_train, t_train, nu, pinn)

  d_loss = data_loss(u, v, p, u_n_train, v_n_train, p_n_train, criterion)
  f_loss = physics_loss(f, g, h, zeros_train, criterion)

  loss = d_loss + f_loss

  losses.append(loss.detach())
  nus.append(nu.item())

  loss_val = loss_val_set(x_val, y_val, t_val, u_val, v_val, p_val, nu, pinn, zeros_train, criterion)
  val_losses.append(loss_val.detach())


  if i%1000 == 0:
    print(f"epochs: {i} and the loss on the training-set is {loss}")
    print(f"epochs: {i} and nu is {nu.item()}")
    print(f"epochs: {i} and the loss on the validation-set is {loss_val}\n")

  loss.backward(retain_graph=True)
  optimizer.step()

torch.save(pinn.state_dict(), '/content/drive/MyDrive/Dataset/noisy5_model_PRJ_T1_50N_6L.pt')
'''
# Out:
# epochs: 0 and the loss on the training-set is 1.0221036672592163
# epochs: 0 and nu is 0.0
# epochs: 0 and the loss on the validation-set is 1.010055661201477
#
# epochs: 1000 and the loss on the training-set is 0.07975819706916809
# epochs: 1000 and nu is 0.03092370554804802
# epochs: 1000 and the loss on the validation-set is 0.08422244340181351
#
# epochs: 2000 and the loss on the training-set is 0.06945239007472992
# epochs: 2000 and nu is 0.033971626311540604
# epochs: 2000 and the loss on the validation-set is 0.07373107224702835
#
# epochs: 3000 and the loss on the training-set is 0.06828680634498596
# epochs: 3000 and nu is 0.03328249230980873
# epochs: 3000 and the loss on the validation-set is 0.07308711111545563
#
# epochs: 4000 and the loss on the training-set is 0.0550495982170105
# epochs: 4000 and nu is 0.030107859522104263
# epochs: 4000 and the loss on the validation-set is 0.059097204357385635
#
# epochs: 5000 and the loss on the training-set is 0.03455246612429619
# epochs: 5000 and nu is 0.02279837243258953
# epochs: 5000 and the loss on the validation-set is 0.03761502727866173
#
# epochs: 6000 and the loss on the training-set is 0.024717047810554504
# epochs: 6000 and nu is 0.021831411868333817
# epochs: 6000 and the loss on the validation-set is 0.027081381529569626
#
# epochs: 7000 and the loss on the training-set is 0.01799175515770912
# epochs: 7000 and nu is 0.01973746344447136
# epochs: 7000 and the loss on the validation-set is 0.019931014627218246
#
# epochs: 8000 and the loss on the training-set is 0.012070955708622932
# epochs: 8000 and nu is 0.01816200651228428
# epochs: 8000 and the loss on the validation-set is 0.013905840925872326
#
# epochs: 9000 and the loss on the training-set is 0.008681055158376694
# epochs: 9000 and nu is 0.0168424341827631
# epochs: 9000 and the loss on the validation-set is 0.010098795406520367
#
# epochs: 10000 and the loss on the training-set is 0.006583208218216896
# epochs: 10000 and nu is 0.015789572149515152
# epochs: 10000 and the loss on the validation-set is 0.0075871446169912815
#
# epochs: 11000 and the loss on the training-set is 0.005556934513151646
# epochs: 11000 and nu is 0.015390744432806969
# epochs: 11000 and the loss on the validation-set is 0.006311662495136261
#
# epochs: 12000 and the loss on the training-set is 0.004450144246220589
# epochs: 12000 and nu is 0.014836573973298073
# epochs: 12000 and the loss on the validation-set is 0.0051293992437422276
#
# epochs: 13000 and the loss on the training-set is 0.003851275658234954
# epochs: 13000 and nu is 0.014272250235080719
# epochs: 13000 and the loss on the validation-set is 0.0044362531043589115
#
# epochs: 14000 and the loss on the training-set is 0.003776253666728735
# epochs: 14000 and nu is 0.013950413092970848
# epochs: 14000 and the loss on the validation-set is 0.00433737738057971
#
# epochs: 15000 and the loss on the training-set is 0.003192007541656494
# epochs: 15000 and nu is 0.013678425922989845
# epochs: 15000 and the loss on the validation-set is 0.0036625671200454235
#
# epochs: 16000 and the loss on the training-set is 0.0027937814593315125
# epochs: 16000 and nu is 0.013467559590935707
# epochs: 16000 and the loss on the validation-set is 0.003170154057443142
#
# epochs: 17000 and the loss on the training-set is 0.0023500956594944
# epochs: 17000 and nu is 0.01320392545312643
# epochs: 17000 and the loss on the validation-set is 0.0026742536574602127
#
# epochs: 18000 and the loss on the training-set is 0.002268218668177724
# epochs: 18000 and nu is 0.013032390736043453
# epochs: 18000 and the loss on the validation-set is 0.002528212033212185
#
# epochs: 19000 and the loss on the training-set is 0.002055891091004014
# epochs: 19000 and nu is 0.012875869870185852
# epochs: 19000 and the loss on the validation-set is 0.002308871131390333
#
# epochs: 20000 and the loss on the training-set is 0.0018004467710852623
# epochs: 20000 and nu is 0.012757990509271622
# epochs: 20000 and the loss on the validation-set is 0.0020099144894629717
#
# epochs: 21000 and the loss on the training-set is 0.001664424897171557
# epochs: 21000 and nu is 0.012590829282999039
# epochs: 21000 and the loss on the validation-set is 0.0018518660217523575
#
# epochs: 22000 and the loss on the training-set is 0.001503766980022192
# epochs: 22000 and nu is 0.012400338426232338
# epochs: 22000 and the loss on the validation-set is 0.0016630133613944054
#
# epochs: 23000 and the loss on the training-set is 0.0017051153117790818
# epochs: 23000 and nu is 0.012283285148441792
# epochs: 23000 and the loss on the validation-set is 0.0018314698245376348
#
# epochs: 24000 and the loss on the training-set is 0.0014935089275240898
# epochs: 24000 and nu is 0.01218503713607788
# epochs: 24000 and the loss on the validation-set is 0.001635455060750246
#
# epochs: 25000 and the loss on the training-set is 0.0014963292051106691
# epochs: 25000 and nu is 0.012148664332926273
# epochs: 25000 and the loss on the validation-set is 0.001665028277784586
#
# epochs: 26000 and the loss on the training-set is 0.0014444019179791212
# epochs: 26000 and nu is 0.011977768503129482
# epochs: 26000 and the loss on the validation-set is 0.0015396577073261142
#
# epochs: 27000 and the loss on the training-set is 0.001166914589703083
# epochs: 27000 and nu is 0.01190902292728424
# epochs: 27000 and the loss on the validation-set is 0.001276289694942534
#
# epochs: 28000 and the loss on the training-set is 0.0013355440460145473
# epochs: 28000 and nu is 0.01186673529446125
# epochs: 28000 and the loss on the validation-set is 0.0014569319318979979
#
# epochs: 29000 and the loss on the training-set is 0.0015612487914040685
# epochs: 29000 and nu is 0.011768645606935024
# epochs: 29000 and the loss on the validation-set is 0.001626831479370594
#
# epochs: 30000 and the loss on the training-set is 0.00111483340151608
# epochs: 30000 and nu is 0.011727391742169857
# epochs: 30000 and the loss on the validation-set is 0.0012265617260709405
#
# epochs: 31000 and the loss on the training-set is 0.0010675417724996805
# epochs: 31000 and nu is 0.011637064628303051
# epochs: 31000 and the loss on the validation-set is 0.00117122707888484
#
# epochs: 32000 and the loss on the training-set is 0.000949398847296834
# epochs: 32000 and nu is 0.011631530709564686
# epochs: 32000 and the loss on the validation-set is 0.001054425723850727
#
# epochs: 33000 and the loss on the training-set is 0.0013361304299905896
# epochs: 33000 and nu is 0.011611892841756344
# epochs: 33000 and the loss on the validation-set is 0.0014839288778603077
#
# epochs: 34000 and the loss on the training-set is 0.000931893999222666
# epochs: 34000 and nu is 0.011507302522659302
# epochs: 34000 and the loss on the validation-set is 0.0010363950859755278
#
# epochs: 35000 and the loss on the training-set is 0.0009532629046589136
# epochs: 35000 and nu is 0.011540292762219906
# epochs: 35000 and the loss on the validation-set is 0.0010942958761006594
#
# epochs: 36000 and the loss on the training-set is 0.0008420065278187394
# epochs: 36000 and nu is 0.01145393867045641
# epochs: 36000 and the loss on the validation-set is 0.0009315497009083629
#
# epochs: 37000 and the loss on the training-set is 0.0008647816721349955
# epochs: 37000 and nu is 0.011442524380981922
# epochs: 37000 and the loss on the validation-set is 0.0009743059054017067
#
# epochs: 38000 and the loss on the training-set is 0.0009316606447100639
# epochs: 38000 and nu is 0.011456051841378212
# epochs: 38000 and the loss on the validation-set is 0.001052208710461855
#
# epochs: 39000 and the loss on the training-set is 0.0008231254178099334
# epochs: 39000 and nu is 0.01138434000313282
# epochs: 39000 and the loss on the validation-set is 0.0009354024659842253
#
# epochs: 40000 and the loss on the training-set is 0.0007656099041923881
# epochs: 40000 and nu is 0.011344369500875473
# epochs: 40000 and the loss on the validation-set is 0.0008480785763822496
#
# epochs: 41000 and the loss on the training-set is 0.000776172848418355
# epochs: 41000 and nu is 0.01135775912553072
# epochs: 41000 and the loss on the validation-set is 0.0008768680272623897
#
# epochs: 42000 and the loss on the training-set is 0.0008145488682202995
# epochs: 42000 and nu is 0.011368700303137302
# epochs: 42000 and the loss on the validation-set is 0.0009324505226686597
#
# epochs: 43000 and the loss on the training-set is 0.0008052028715610504
# epochs: 43000 and nu is 0.011318124830722809
# epochs: 43000 and the loss on the validation-set is 0.0009208695264533162
#
# epochs: 44000 and the loss on the training-set is 0.0006813843501731753
# epochs: 44000 and nu is 0.011284688487648964
# epochs: 44000 and the loss on the validation-set is 0.0007832194678485394
#
# epochs: 45000 and the loss on the training-set is 0.0007871059351600707
# epochs: 45000 and nu is 0.011252004653215408
# epochs: 45000 and the loss on the validation-set is 0.0008613421814516187
#
# epochs: 46000 and the loss on the training-set is 0.0007577590877190232
# epochs: 46000 and nu is 0.011213082820177078
# epochs: 46000 and the loss on the validation-set is 0.0008145178435370326
#
# epochs: 47000 and the loss on the training-set is 0.0007472200086340308
# epochs: 47000 and nu is 0.011280556209385395
# epochs: 47000 and the loss on the validation-set is 0.0008416875498369336
#
# epochs: 48000 and the loss on the training-set is 0.0006458327989093959
# epochs: 48000 and nu is 0.011202110908925533
# epochs: 48000 and the loss on the validation-set is 0.00072417629417032
#
# epochs: 49000 and the loss on the training-set is 0.0006699732621200383
# epochs: 49000 and nu is 0.011166063137352467
# epochs: 49000 and the loss on the validation-set is 0.0007400090107694268
#
# epochs: 50000 and the loss on the training-set is 0.0006443428574129939
# epochs: 50000 and nu is 0.011171332560479641
# epochs: 50000 and the loss on the validation-set is 0.0007323281606659293
#
# epochs: 51000 and the loss on the training-set is 0.0006003045127727091
# epochs: 51000 and nu is 0.01116076298058033
# epochs: 51000 and the loss on the validation-set is 0.0006923208711668849
#
# epochs: 52000 and the loss on the training-set is 0.0007248473702929914
# epochs: 52000 and nu is 0.011184538714587688
# epochs: 52000 and the loss on the validation-set is 0.0008262412156909704
#
# epochs: 53000 and the loss on the training-set is 0.0006325398571789265
# epochs: 53000 and nu is 0.011131576262414455
# epochs: 53000 and the loss on the validation-set is 0.0007206602022051811
#
# epochs: 54000 and the loss on the training-set is 0.0005845093401148915
# epochs: 54000 and nu is 0.01110516395419836
# epochs: 54000 and the loss on the validation-set is 0.0006619163905270398
#
# epochs: 55000 and the loss on the training-set is 0.0006550909020006657
# epochs: 55000 and nu is 0.011073727160692215
# epochs: 55000 and the loss on the validation-set is 0.000718934868928045
#
# epochs: 56000 and the loss on the training-set is 0.000569732510484755
# epochs: 56000 and nu is 0.011081131175160408
# epochs: 56000 and the loss on the validation-set is 0.000649718102067709
#
# epochs: 57000 and the loss on the training-set is 0.0006230497383512557
# epochs: 57000 and nu is 0.011053437367081642
# epochs: 57000 and the loss on the validation-set is 0.0007131738238967955
#
# epochs: 58000 and the loss on the training-set is 0.0005917964735999703
# epochs: 58000 and nu is 0.011011113412678242
# epochs: 58000 and the loss on the validation-set is 0.0006555611616931856
#
# epochs: 59000 and the loss on the training-set is 0.0006142041529528797
# epochs: 59000 and nu is 0.01104902382940054
# epochs: 59000 and the loss on the validation-set is 0.0007076134206727147
#
# epochs: 60000 and the loss on the training-set is 0.0006081340834498405
# epochs: 60000 and nu is 0.0110124247148633
# epochs: 60000 and the loss on the validation-set is 0.0006658174097537994
#
# epochs: 61000 and the loss on the training-set is 0.0005486722802743316
# epochs: 61000 and nu is 0.010999276302754879
# epochs: 61000 and the loss on the validation-set is 0.0006082636537030339
#
# epochs: 62000 and the loss on the training-set is 0.0005465970025397837
# epochs: 62000 and nu is 0.011001182720065117
# epochs: 62000 and the loss on the validation-set is 0.0006128351669758558
#
# epochs: 63000 and the loss on the training-set is 0.000568744377233088
# epochs: 63000 and nu is 0.010944688692688942
# epochs: 63000 and the loss on the validation-set is 0.0006193048902787268
#
# epochs: 64000 and the loss on the training-set is 0.0005549730849452317
# epochs: 64000 and nu is 0.010960710234940052
# epochs: 64000 and the loss on the validation-set is 0.0006003575981594622
#
# epochs: 65000 and the loss on the training-set is 0.000527212570887059
# epochs: 65000 and nu is 0.010935786180198193
# epochs: 65000 and the loss on the validation-set is 0.0005788536509498954
#
# epochs: 66000 and the loss on the training-set is 0.0005514998338185251
# epochs: 66000 and nu is 0.010920722037553787
# epochs: 66000 and the loss on the validation-set is 0.0006040802109055221
#
# epochs: 67000 and the loss on the training-set is 0.0006189653067849576
# epochs: 67000 and nu is 0.010893196798861027
# epochs: 67000 and the loss on the validation-set is 0.000669565110001713
#
# epochs: 68000 and the loss on the training-set is 0.0005156907136552036
# epochs: 68000 and nu is 0.010888849385082722
# epochs: 68000 and the loss on the validation-set is 0.0005520090344361961
#
# epochs: 69000 and the loss on the training-set is 0.0005231971153989434
# epochs: 69000 and nu is 0.010889576748013496
# epochs: 69000 and the loss on the validation-set is 0.0005762005457654595
#
# epochs: 70000 and the loss on the training-set is 0.0005745911621488631
# epochs: 70000 and nu is 0.010861312970519066
# epochs: 70000 and the loss on the validation-set is 0.0006035534897819161
#
# epochs: 71000 and the loss on the training-set is 0.0005052823107689619
# epochs: 71000 and nu is 0.01087120734155178
# epochs: 71000 and the loss on the validation-set is 0.0005441588000394404
#
# epochs: 72000 and the loss on the training-set is 0.0005079551483504474
# epochs: 72000 and nu is 0.010843977332115173
# epochs: 72000 and the loss on the validation-set is 0.0005354488966986537
#
# epochs: 73000 and the loss on the training-set is 0.000520027824677527
# epochs: 73000 and nu is 0.010825840756297112
# epochs: 73000 and the loss on the validation-set is 0.0005368742858991027
#
# epochs: 74000 and the loss on the training-set is 0.0005324055091477931
# epochs: 74000 and nu is 0.01082515437155962
# epochs: 74000 and the loss on the validation-set is 0.0005509714828804135
#
# epochs: 75000 and the loss on the training-set is 0.0005256224540062249
# epochs: 75000 and nu is 0.010828323662281036
# epochs: 75000 and the loss on the validation-set is 0.000553167425096035
#
# epochs: 76000 and the loss on the training-set is 0.0005204060580581427
# epochs: 76000 and nu is 0.010815500281751156
# epochs: 76000 and the loss on the validation-set is 0.0005387330893427134
#
# epochs: 77000 and the loss on the training-set is 0.0004963295068591833
# epochs: 77000 and nu is 0.010823076590895653
# epochs: 77000 and the loss on the validation-set is 0.0005151028162799776
#
# epochs: 78000 and the loss on the training-set is 0.0005022499826736748
# epochs: 78000 and nu is 0.010772712528705597
# epochs: 78000 and the loss on the validation-set is 0.0005017537041567266
#
# epochs: 79000 and the loss on the training-set is 0.0005880633252672851
# epochs: 79000 and nu is 0.010764985345304012
# epochs: 79000 and the loss on the validation-set is 0.0005943801370449364
#
# epochs: 80000 and the loss on the training-set is 0.00054190494120121
# epochs: 80000 and nu is 0.010750063695013523
# epochs: 80000 and the loss on the validation-set is 0.0005415449268184602
#
# epochs: 81000 and the loss on the training-set is 0.000491015671286732
# epochs: 81000 and nu is 0.010755237191915512
# epochs: 81000 and the loss on the validation-set is 0.000495677231810987
#
# epochs: 82000 and the loss on the training-set is 0.0006415115785785019
# epochs: 82000 and nu is 0.010731766000390053
# epochs: 82000 and the loss on the validation-set is 0.0006307612056843936
#
# epochs: 83000 and the loss on the training-set is 0.0004924465902149677
# epochs: 83000 and nu is 0.010704057291150093
# epochs: 83000 and the loss on the validation-set is 0.00048503349535167217
#
# epochs: 84000 and the loss on the training-set is 0.0005098685505799949
# epochs: 84000 and nu is 0.010725383646786213
# epochs: 84000 and the loss on the validation-set is 0.0005164491012692451
#
# epochs: 85000 and the loss on the training-set is 0.0004675197706092149
# epochs: 85000 and nu is 0.01072589959949255
# epochs: 85000 and the loss on the validation-set is 0.00045672428677789867
#
# epochs: 86000 and the loss on the training-set is 0.0005102919531054795
# epochs: 86000 and nu is 0.010710414499044418
# epochs: 86000 and the loss on the validation-set is 0.0005031118635088205
#
# epochs: 87000 and the loss on the training-set is 0.000895695760846138
# epochs: 87000 and nu is 0.01064810436218977
# epochs: 87000 and the loss on the validation-set is 0.0008986811735667288
#
# epochs: 88000 and the loss on the training-set is 0.0005683585768565536
# epochs: 88000 and nu is 0.010663793422281742
# epochs: 88000 and the loss on the validation-set is 0.0005325276870280504
#
# epochs: 89000 and the loss on the training-set is 0.0005533162620849907
# epochs: 89000 and nu is 0.010703563690185547
# epochs: 89000 and the loss on the validation-set is 0.0005190229858271778
#
# epochs: 90000 and the loss on the training-set is 0.000464551238110289
# epochs: 90000 and nu is 0.010690501891076565
# epochs: 90000 and the loss on the validation-set is 0.00044370206887833774
#
# epochs: 91000 and the loss on the training-set is 0.0005274808499962091
# epochs: 91000 and nu is 0.010628785938024521
# epochs: 91000 and the loss on the validation-set is 0.00048520724521949887
#
# epochs: 92000 and the loss on the training-set is 0.0004713770467787981
# epochs: 92000 and nu is 0.010662224143743515
# epochs: 92000 and the loss on the validation-set is 0.0004492772277444601
#
# epochs: 93000 and the loss on the training-set is 0.00046315189683809876
# epochs: 93000 and nu is 0.01065853051841259
# epochs: 93000 and the loss on the validation-set is 0.00044713812530972064
#
# epochs: 94000 and the loss on the training-set is 0.00045250740367919207
# epochs: 94000 and nu is 0.010656708851456642
# epochs: 94000 and the loss on the validation-set is 0.00042770226718857884
#
# epochs: 95000 and the loss on the training-set is 0.0005096911918371916
# epochs: 95000 and nu is 0.010584423318505287
# epochs: 95000 and the loss on the validation-set is 0.00047178700333461165
#
# epochs: 96000 and the loss on the training-set is 0.00046299895620904863
# epochs: 96000 and nu is 0.010629883967339993
# epochs: 96000 and the loss on the validation-set is 0.0004320415901020169
#
# epochs: 97000 and the loss on the training-set is 0.0005303101497702301
# epochs: 97000 and nu is 0.010602762922644615
# epochs: 97000 and the loss on the validation-set is 0.0004949336871504784
#
# epochs: 98000 and the loss on the training-set is 0.000450849998742342
# epochs: 98000 and nu is 0.010614042170345783
# epochs: 98000 and the loss on the validation-set is 0.000417828734498471
#
# epochs: 99000 and the loss on the training-set is 0.0004421628837008029
# epochs: 99000 and nu is 0.010607616975903511
# epochs: 99000 and the loss on the validation-set is 0.0004099145298823714
#
# epochs: 100000 and the loss on the training-set is 0.0004708333872258663
# epochs: 100000 and nu is 0.010634132660925388
# epochs: 100000 and the loss on the validation-set is 0.00044089258881285787
#
# epochs: 101000 and the loss on the training-set is 0.000550370488781482
# epochs: 101000 and nu is 0.010567296296358109
# epochs: 101000 and the loss on the validation-set is 0.0005010755849070847
#
# epochs: 102000 and the loss on the training-set is 0.0004869936965405941
# epochs: 102000 and nu is 0.010590397752821445
# epochs: 102000 and the loss on the validation-set is 0.0004611699841916561
#
# epochs: 103000 and the loss on the training-set is 0.0005154656828381121
# epochs: 103000 and nu is 0.01054476574063301
# epochs: 103000 and the loss on the validation-set is 0.0004761832533404231
#
# epochs: 104000 and the loss on the training-set is 0.0005683618364855647
# epochs: 104000 and nu is 0.01057400368154049
# epochs: 104000 and the loss on the validation-set is 0.0005263299099169672
#
# epochs: 105000 and the loss on the training-set is 0.0004512824525590986
# epochs: 105000 and nu is 0.010578091256320477
# epochs: 105000 and the loss on the validation-set is 0.00041771316318772733
#
# epochs: 106000 and the loss on the training-set is 0.0005019927630200982
# epochs: 106000 and nu is 0.010587453842163086
# epochs: 106000 and the loss on the validation-set is 0.00046935153659433126
#
# epochs: 107000 and the loss on the training-set is 0.000461261544842273
# epochs: 107000 and nu is 0.010559343732893467
# epochs: 107000 and the loss on the validation-set is 0.0004302887537050992
#
# epochs: 108000 and the loss on the training-set is 0.00043920919415540993
# epochs: 108000 and nu is 0.010561349801719189
# epochs: 108000 and the loss on the validation-set is 0.00039984137401916087
#
# epochs: 109000 and the loss on the training-set is 0.0004321820451878011
# epochs: 109000 and nu is 0.010545891709625721
# epochs: 109000 and the loss on the validation-set is 0.0003923516196664423
#
# epochs: 110000 and the loss on the training-set is 0.0005427278811112046
# epochs: 110000 and nu is 0.010506185702979565
# epochs: 110000 and the loss on the validation-set is 0.0004744201432913542
#
# epochs: 111000 and the loss on the training-set is 0.00044731691014021635
# epochs: 111000 and nu is 0.010556211695075035
# epochs: 111000 and the loss on the validation-set is 0.0004046997055411339
#
# epochs: 112000 and the loss on the training-set is 0.0004456302267499268
# epochs: 112000 and nu is 0.010515944100916386
# epochs: 112000 and the loss on the validation-set is 0.00040183172677643597
#
# epochs: 113000 and the loss on the training-set is 0.0004503163509070873
# epochs: 113000 and nu is 0.010516791604459286
# epochs: 113000 and the loss on the validation-set is 0.0004083146050106734
#
# epochs: 114000 and the loss on the training-set is 0.0005394846084527671
# epochs: 114000 and nu is 0.010510602034628391
# epochs: 114000 and the loss on the validation-set is 0.000499032496009022
#
# epochs: 115000 and the loss on the training-set is 0.00044170874753035605
# epochs: 115000 and nu is 0.010490993969142437
# epochs: 115000 and the loss on the validation-set is 0.0003920621529687196
#
# epochs: 116000 and the loss on the training-set is 0.0004455302550923079
# epochs: 116000 and nu is 0.01049268338829279
# epochs: 116000 and the loss on the validation-set is 0.0004030168638564646
#
# epochs: 117000 and the loss on the training-set is 0.0004560524830594659
# epochs: 117000 and nu is 0.010499384254217148
# epochs: 117000 and the loss on the validation-set is 0.00041325390338897705
#
# epochs: 118000 and the loss on the training-set is 0.00044590263860300183
# epochs: 118000 and nu is 0.010469723492860794
# epochs: 118000 and the loss on the validation-set is 0.00040109403198584914
#
# epochs: 119000 and the loss on the training-set is 0.0005950094782747328
# epochs: 119000 and nu is 0.010471377521753311
# epochs: 119000 and the loss on the validation-set is 0.0005537865217775106
#
# epochs: 120000 and the loss on the training-set is 0.00043478221050463617
# epochs: 120000 and nu is 0.010457560420036316
# epochs: 120000 and the loss on the validation-set is 0.000390526169212535
#
# epochs: 121000 and the loss on the training-set is 0.00046392029616981745
# epochs: 121000 and nu is 0.01049618236720562
# epochs: 121000 and the loss on the validation-set is 0.00041322855395264924
#
# epochs: 122000 and the loss on the training-set is 0.00043077621376141906
# epochs: 122000 and nu is 0.010450191795825958
# epochs: 122000 and the loss on the validation-set is 0.00038204665179364383
#
# epochs: 123000 and the loss on the training-set is 0.0005051239859312773
# epochs: 123000 and nu is 0.010420173406600952
# epochs: 123000 and the loss on the validation-set is 0.00044268122292123735
#
# epochs: 124000 and the loss on the training-set is 0.00045447199954651296
# epochs: 124000 and nu is 0.01045579556375742
# epochs: 124000 and the loss on the validation-set is 0.00040952395647764206
#
# epochs: 125000 and the loss on the training-set is 0.00042097526602447033
# epochs: 125000 and nu is 0.010444290935993195
# epochs: 125000 and the loss on the validation-set is 0.000373645918443799
#
# epochs: 126000 and the loss on the training-set is 0.00043310923501849174
# epochs: 126000 and nu is 0.01042014081031084
# epochs: 126000 and the loss on the validation-set is 0.00038589973701164126
#
# epochs: 127000 and the loss on the training-set is 0.00045657361624762416
# epochs: 127000 and nu is 0.010467663407325745
# epochs: 127000 and the loss on the validation-set is 0.00041038080235011876
#
# epochs: 128000 and the loss on the training-set is 0.0004527184064500034
# epochs: 128000 and nu is 0.010454181581735611
# epochs: 128000 and the loss on the validation-set is 0.000395977811422199
#
# epochs: 129000 and the loss on the training-set is 0.0006524530472233891
# epochs: 129000 and nu is 0.010490592569112778
# epochs: 129000 and the loss on the validation-set is 0.0006253242027014494
#
# epochs: 130000 and the loss on the training-set is 0.00047050314606167376
# epochs: 130000 and nu is 0.010391278192400932
# epochs: 130000 and the loss on the validation-set is 0.00041807215893641114
#
# epochs: 131000 and the loss on the training-set is 0.00044933403842151165
# epochs: 131000 and nu is 0.010431147180497646
# epochs: 131000 and the loss on the validation-set is 0.0004008846590295434
#
# epochs: 132000 and the loss on the training-set is 0.0004288455529604107
# epochs: 132000 and nu is 0.010419606231153011
# epochs: 132000 and the loss on the validation-set is 0.00038379430770874023
#
# epochs: 133000 and the loss on the training-set is 0.0004700169083662331
# epochs: 133000 and nu is 0.010387285612523556
# epochs: 133000 and the loss on the validation-set is 0.00042408055742271245
#
# epochs: 134000 and the loss on the training-set is 0.0004283753514755517
# epochs: 134000 and nu is 0.010406057350337505
# epochs: 134000 and the loss on the validation-set is 0.00037730636540800333
#
# epochs: 135000 and the loss on the training-set is 0.00041499926010146737
# epochs: 135000 and nu is 0.010396796278655529
# epochs: 135000 and the loss on the validation-set is 0.00036353268660604954
#
# epochs: 136000 and the loss on the training-set is 0.0004437561146914959
# epochs: 136000 and nu is 0.010426634922623634
# epochs: 136000 and the loss on the validation-set is 0.00039028091123327613
#
# epochs: 137000 and the loss on the training-set is 0.00042452994966879487
# epochs: 137000 and nu is 0.01041471678763628
# epochs: 137000 and the loss on the validation-set is 0.00037612582673318684
#
# epochs: 138000 and the loss on the training-set is 0.00043835685937665403
# epochs: 138000 and nu is 0.0103891771286726
# epochs: 138000 and the loss on the validation-set is 0.00039076971006579697
#
# epochs: 139000 and the loss on the training-set is 0.00041762180626392365
# epochs: 139000 and nu is 0.010395255871117115
# epochs: 139000 and the loss on the validation-set is 0.00036245828960090876
#
# epochs: 140000 and the loss on the training-set is 0.0004215587687212974
# epochs: 140000 and nu is 0.010394829325377941
# epochs: 140000 and the loss on the validation-set is 0.0003695784544106573
#
# epochs: 141000 and the loss on the training-set is 0.00042796190246008337
# epochs: 141000 and nu is 0.010375676676630974
# epochs: 141000 and the loss on the validation-set is 0.0003802838909905404
#
# epochs: 142000 and the loss on the training-set is 0.0004232103528920561
# epochs: 142000 and nu is 0.010381270200014114
# epochs: 142000 and the loss on the validation-set is 0.0003709880693349987
#
# epochs: 143000 and the loss on the training-set is 0.00041964149568229914
# epochs: 143000 and nu is 0.010408884845674038
# epochs: 143000 and the loss on the validation-set is 0.0003698169894050807
#
# epochs: 144000 and the loss on the training-set is 0.0004113367758691311
# epochs: 144000 and nu is 0.010379246436059475
# epochs: 144000 and the loss on the validation-set is 0.0003614805464167148
#
# epochs: 145000 and the loss on the training-set is 0.0004248869663570076
# epochs: 145000 and nu is 0.010363082401454449
# epochs: 145000 and the loss on the validation-set is 0.00037094723666086793
#
# epochs: 146000 and the loss on the training-set is 0.00040995440213009715
# epochs: 146000 and nu is 0.010367590002715588
# epochs: 146000 and the loss on the validation-set is 0.00035786780063062906
#
# epochs: 147000 and the loss on the training-set is 0.0004535893094725907
# epochs: 147000 and nu is 0.01039701048284769
# epochs: 147000 and the loss on the validation-set is 0.00039968162309378386
#
# epochs: 148000 and the loss on the training-set is 0.00052145856898278
# epochs: 148000 and nu is 0.010417822748422623
# epochs: 148000 and the loss on the validation-set is 0.00047154456842690706
#
# epochs: 149000 and the loss on the training-set is 0.00044595185318030417
# epochs: 149000 and nu is 0.010351764969527721
# epochs: 149000 and the loss on the validation-set is 0.0003886491758748889
#
# epochs: 150000 and the loss on the training-set is 0.00041705850162543356
# epochs: 150000 and nu is 0.010371921584010124
# epochs: 150000 and the loss on the validation-set is 0.0003619528724811971

# %%
'''
#salva
losses_t = torch.tensor(losses)
val_losses_t = torch.tensor(val_losses)
nus_t = torch.tensor(nus)
df_save_loss = pd.DataFrame({'training_loss': losses_t, 'validation_loss': val_losses_t, 'lamda1': nus_t})
df_save_loss.to_csv('/content/drive/MyDrive/Dataset/noisy5_data_loss_nu_50_6.csv', index=False)
'''

# %%
df_loss_data = pd.read_csv('/content/drive/MyDrive/Dataset/noisy5_data_loss_nu_50_6.csv')

# %%
df_loss_data.head()
# Out:
#    training_loss  validation_loss    lamda1
# 0       1.022104         1.010056  0.000000
# 1       0.863301         0.853311 -0.001000
# 2       0.722810         0.714873 -0.001983
# 3       0.597317         0.591504 -0.002947
# 4       0.485762         0.482231 -0.003894

# %%
training_loss = df_loss_data['training_loss'].values
validation_loss = df_loss_data['validation_loss'].values
nu = df_loss_data['lamda1'].values

# %%
len(nu)
# Out:
# 150001

# %%
x_plot = np.arange(151)

plt.plot(x_plot,training_loss[::1000],'o',linestyle='--',markersize=3, label='Training Loss',color='red')
plt.plot(x_plot,validation_loss[::1000],marker='o',linestyle='--',markersize=3, color='g', label='Validation Loss')

plt.ylim(bottom=0,top=0.0030)
plt.xlabel(r'Epochs $\times 10^3$')
plt.ylabel('M.S.E.')
plt.xticks([0,25,50,75,100,125,150])

plt.legend()
plt.xlim(left=0)
#metti y in notazione scentifica
# Out:
# (0.0, 157.5)

# %%
new_model = FCN(3,3,50,6).to(device)
new_model.load_state_dict(torch.load('/content/drive/MyDrive/Dataset/noisy5_model_PRJ_T1_50N_6L.pt', map_location=torch.device('cpu')))

with torch.no_grad():
  plot_pinn = new_model(torch.hstack((x_test, y_test, t_test)))
  u_plot = plot_pinn[:, 0:1]
  v_plot = plot_pinn[:, 1:2]
  p_plot = plot_pinn[:, 2:3]

# %%
x_plot = np.reshape(x_test.cpu().detach().numpy(), (50, 100))
y_plot = np.reshape(y_test.cpu().detach().numpy(), (50, 100))

# %%
pression_plot_true = np.reshape(p_test.cpu().detach().numpy(), (50, 100))
plt.figure(figsize=(5, 2))
plt.contourf(x_plot, y_plot, pression_plot_true, levels=80, cmap="rainbow")
plt.colorbar()
plt.title('Exact pressure')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
pression_plot_pinn = np.reshape(p_plot.cpu().detach().numpy(), (50, 100))
plt.figure(figsize=(5, 2))
plt.contourf(x_plot, y_plot, pression_plot_pinn, levels=80, cmap="rainbow")
plt.colorbar()
plt.title('Predicted pressure (5% noise)')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
u_plot_true = np.reshape(u_test.cpu().detach().numpy(), (50, 100))
plt.figure(figsize=(5, 2))
plt.contourf(x_plot, y_plot, u_plot_true, levels=80, cmap="rainbow")
plt.colorbar()
plt.title('Exact u')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
u_plot_pinn = np.reshape(u_plot.cpu().detach().numpy(), (50, 100))
plt.figure(figsize=(5, 2))
plt.contourf(x_plot, y_plot, u_plot_pinn, levels=80, cmap="rainbow")
plt.colorbar()
plt.title('Predicted u (5% noise)')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
v_plot_true = np.reshape(v_test.cpu().detach().numpy(), (50, 100))
plt.figure(figsize=(5, 2))
plt.contourf(x_plot, y_plot, v_plot_true, levels=80, cmap="rainbow")
plt.colorbar()
plt.title('Exact v')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
v_plot_pinn = np.reshape(v_plot.cpu().detach().numpy(), (50, 100))
plt.figure(figsize=(5, 2))
plt.contourf(x_plot, y_plot, v_plot_pinn, levels=80, cmap="rainbow")
plt.colorbar()
plt.title('Predicted v (5% noise)')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
p_error = ((p_plot.reshape(1,-1) - p_test.reshape(1,-1)).norm() / p_test.reshape(1,-1).norm())*100
print(f'The error on p is {p_error:.2f} %')
# Out:
# The error on p is 1.82 %

# %%
u_error = ((u_plot.reshape(1,-1) - u_test.reshape(1,-1)).norm() / u_test.reshape(1,-1).norm())*100
print(f'The error on u is {u_error:.2f} %')
# Out:
# The error on u is 0.57 %

# %%
v_error = ((v_plot.reshape(1,-1) - v_test.reshape(1,-1)).norm() / v_test.reshape(1,-1).norm())*100
print(f'The error on v is {v_error:.2f} %')
# Out:
# The error on v is 1.51 %

# %%
lamda_error =( abs(nu[-1]-0.01)/0.01)*100
print(f'The error on lambda is {lamda_error:.2f} %')
# Out:
# The error on lambda is 3.72 %
